# %%
'''Instagram is a very popular social media app that people use for promoting businesses, blogging, and creating content.
To do well on Instagram, it's important to understand how your posts are reaching people. In this guide, I'll show you how to use Python to analyze and predict the reach of your Instagram posts.
I've been collecting data on my Instagram posts to see how well they do. If you want to analyze your reach, you can collect your data too.
In this guide, we'll use my data to learn how to look at different metrics like likes, comments, shares, and saves. Then, we'll use a machine learning model to predict how well future posts might do.
data = {
'likes': [100, 150, 200, 250, 300],
'comments': [10, 15, 20, 25, 30],
'shares': [5, 10, 15, 20, 25],
'hashtags': [3, 4, 2, 5, 6],
'day_of_week': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
'reach': [1000, 1500, 2000, 2500, 3000]
}

TASKS:
Data Collection on Instagram posts, such as likes, comments, and shares
Visualize data using bar charts and scatter plots.
The concept of linear regression by explaining how one variable (likes) might predict another (comments).
The concept of logistic regression, which is used for binary classification. Describe how this method can predict whether a post will get more than a certain number of likes.'''

# %%
import pandas as pd
data = {
    'likes': [100, 150, 200, 250, 300],
    'comments': [10, 15, 20, 25, 30],
    'shares': [5, 10, 15, 20, 25],
    'hashtags': [3, 4, 2, 5, 6],
    'day_of_week': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
    'reach': [1000, 1500, 2000, 2500, 3000]
}
df = pd.DataFrame(data)
print(df)
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df)
plt.show()
from sklearn.linear_model import LinearRegression
X = df[['likes']]
Y = df[['reach']]
model = LinearRegression()
model.fit(X, y)
# Out:
#    likes  comments  shares  hashtags day_of_week  reach
# 0    100        10       5         3      Monday   1000
# 1    150        15      10         4     Tuesday   1500
# 2    200        20      15         2   Wednesday   2000
# 3    250        25      20         5    Thursday   2500
# 4    300        30      25         6      Friday   3000
# LinearRegression()

# %%
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Likes')
plt.ylabel('Reach')
plt.title('Likes vs. Reach')
plt.show()
df['popular'] = df['reach'] > 2000
print(df)

from sklearn.linear_model import LogisticRegression
X = df()
y = df

log_model = LogisticRegression
log_model.fit(X,y)
#visualizing
df['predicted_popular'] = log_model.predict(X)
print(df)
likes = int(input("Enter the number of likes: "))
comments = int(input("Enter the number of comments: "))
shares = int(input("Enter the number of shares: "))
hashtag=s = int(input("Enter the number of hashtags:"))
predicted_reach = model.predict([[likes]])[0]
predicted_popularity = log_model.predict([[likes, comments, shares, hashtags]])[0]
# Out:
#    likes  comments  shares  hashtags day_of_week  reach  popular
# 0    100        10       5         3      Monday   1000    False
# 1    150        15      10         4     Tuesday   1500    False
# 2    200        20      15         2   Wednesday   2000    False
# 3    250        25      20         5    Thursday   2500     True
# 4    300        30      25         6      Friday   3000     True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-665e757f0a23> in <cell line: 0>()
#       9 from sklearn.linear_model import LogisticRegression
#      10 log_model = LogisticRegression
# ---> 11 log_model.fit(X,Y)
#      12 #visualizing
#      13 df['predicted_popular'] = log_model.predict(X)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1380
# ...

# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
